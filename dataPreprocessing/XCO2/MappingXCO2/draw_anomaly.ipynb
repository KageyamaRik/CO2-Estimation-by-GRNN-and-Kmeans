# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei']  # 中文
plt.rcParams['axes.unicode_minus']=False    # 负号

test = np.load("H:\\XCO2\\MappingXCO2\\MappingXCO2_Anomaly_year_flip\\MappingXCO2_2020.npy")

longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5,89.5,180)
lon, lat = np.meshgrid(longitude, latitude)

plt.rcParams['figure.figsize'] = (12.0, 8.0)
Map = Basemap(llcrnrlon=-180., llcrnrlat=-90., urcrnrlon=180., urcrnrlat=90.)
Map.drawcoastlines()
parallels = np.arange(-75.,76,25.)
# labels = [left,right,top,bottom]
Map.drawparallels(parallels,labels=[True,False,False,False])
meridians = np.arange(0.,361.,60.)
Map.drawmeridians(meridians,labels=[False,False,False,True])

x, y = Map(lon, lat)

mapPlot = Map.pcolor(x, y, test, cmap='viridis', vmin=-2.0, vmax=2.0)
mapPlot.cmap.set_under('w')  # 设置底色
cbar=Map.colorbar(mapPlot, fraction=0.023)
plt.show()
# Out:
# C:\Users\alzio\AppData\Local\Temp\ipykernel_8548\745896485.py:26: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   mapPlot.cmap.set_under('w')  # 设置底色

# %%
for year in range(2009, 2021):
    test = np.load(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_Anomaly_year_flip\\MappingXCO2_{year}.npy")
    out = np.flip(test, axis=0)
    out[np.isnan(out)] = -9999.0
    np.save(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_Anomaly_year\\MappingXCO2_{year}.npy", out)

# %%
test = np.load("H:\\XCO2\\MappingXCO2\\MappingXCO2_Anomaly_year\\MappingXCO2_2020.npy")

longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5,89.5,180)
lon, lat = np.meshgrid(longitude, latitude)

plt.rcParams['figure.figsize'] = (12.0, 8.0)
Map = Basemap(llcrnrlon=-180., llcrnrlat=-90., urcrnrlon=180., urcrnrlat=90.)
Map.drawcoastlines()
parallels = np.arange(-75.,76,25.)
# labels = [left,right,top,bottom]
Map.drawparallels(parallels,labels=[True,False,False,False])
meridians = np.arange(0.,361.,60.)
Map.drawmeridians(meridians,labels=[False,False,False,True])

x, y = Map(lon, lat)

mapPlot = Map.pcolor(x, y, test, cmap='viridis', vmin=-2.0, vmax=2.0)
mapPlot.cmap.set_under('w')  # 设置底色
cbar=Map.colorbar(mapPlot, fraction=0.023)
plt.show()
# Out:
# C:\Users\alzio\AppData\Local\Temp\ipykernel_8548\68229834.py:19: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   mapPlot.cmap.set_under('w')  # 设置底色
