# %%
# 检验非排放区
import matplotlib.pyplot as plt
import numpy as np
from maplot import *

plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False
from matplotlib.ticker import MaxNLocator
from mpl_toolkits.basemap import Basemap

china_shp_path = ("H:\\Region\\全国shp\\china_line", "china_line")  # 中国陆地轮廓
nine_shp_path = ("H:\\Region\\全国shp\\最新2021年全国行政区划\\九段线", "九段线")  # 九段线
global_shp_path = ("H:\\Region\\世界国家\\世界国家", "世界国家")

figPath = "F:\\Research\\基于卫星遥感的城市尺度碳核算研究\\论文\\A novel method for XCO2 enhancement and its application in modeling CO2 emissions in China\\Drafts202402\\figures\\"

# %%
odiac = np.array([np.load(f"H:\\CO2\\ODIAC\\2022\\year\\ODIAC_{year}.npy") for year in range(2014, 2020)])
odiac_mean = odiac.mean(axis=0)
non_emi = np.zeros_like(odiac_mean)
non_emi[odiac_mean==0.0] = 1.0
non_emi[~(odiac_mean==0.0)] = np.NaN
xco2 = np.array([np.load(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_year\\MappingXCO2_{year}.npy") for year in range(2014, 2020)])
xco2[xco2 == -9999.0] = np.NaN
xco2_mean = xco2.mean(axis=0)


china_area = np.load("china_area.npy")
asia_area = np.load("NNG_judgeRegion.npy")
odiac_mean[~asia_area] = np.NaN  # 非限定的部分亚洲区域

longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5,89.5,180)
lon, lat = np.meshgrid(longitude, latitude)

plt.rcParams['figure.figsize'] = (8.0, 8.0)
Map = Basemap(llcrnrlon=70., llcrnrlat=13., urcrnrlon=140., urcrnrlat=57.)
# Map.drawcoastlines()
parallels = np.arange(0.,76,10.)
# labels = [left,right,top,bottom]
Map.drawparallels(parallels,labels=[True,False,False,False], color="b", linewidth=1.5)
# meridians = np.arange(0.,361.,60.)
# Map.drawmeridians(meridians,labels=[False,False,False,True])
Map.readshapefile(*global_shp_path, default_encoding="GB2312")
Map.readshapefile(*china_shp_path, color="r", linewidth=1.5)

x, y = Map(lon, lat)

mapPlot = Map.pcolor(x, y, xco2_mean, cmap="viridis")
mapPlot2 = Map.pcolor(x, y, non_emi, cmap='Reds', alpha=0.5)
# mapPlot2.cmap.set_under('w')  # 设置底色
for l in range(70, 151):
    Map.plot([l, l-5], [30, 20], color="blue", linewidth=0.5, alpha=0.5)

plt.savefig(figPath+"methods_bkg.jpg", dpi=600, bbox_inches='tight')
plt.show()

# %%
longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5,89.5,180)
lon, lat = np.meshgrid(longitude, latitude)

plt.rcParams['figure.figsize'] = (2.0, 2.0)
plt.axis("off")
Map = Basemap(projection='aea', resolution='l', lat_0=25.0, lon_0=105.,
              llcrnrlon=78., llcrnrlat=15., urcrnrlon=138., urcrnrlat=52.
              )
# Map.drawcoastlines()
# parallels = np.arange(0.,76,10.)
# labels = [left,right,top,bottom]
# Map.drawparallels(parallels,labels=[True,False,False,False], color="b", linewidth=1.5)
# meridians = np.arange(0.,361.,60.)
# Map.drawmeridians(meridians,labels=[False,False,False,True])
Map.readshapefile(*china_shp_path, color="black", linewidth=1.0, antialiased=True)

# x, y = Map(lon, lat)

# mapPlot = Map.pcolor(x, y, xco2_mean, cmap="viridis")
# mapPlot2 = Map.pcolor(x, y, non_emi, cmap='Reds', alpha=0.5)
plt.savefig("F:\\Research\\基于卫星遥感的城市尺度碳核算研究\\论文\\A novel method for XCO2 enhancement and its application in modeling CO2 emissions in China\\Drafts202402\\pics\\china22.png", bbox_inches="tight", pad_inches=0)
plt.show()

# %%
longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5,89.5,180)
lon, lat = np.meshgrid(longitude, latitude)

plt.rcParams['figure.figsize'] = (12.0, 8.0)
Map = Basemap(llcrnrlon=45., llcrnrlat=-12., urcrnrlon=160., urcrnrlat=80.)
Map.drawcoastlines()
parallels = np.arange(-75.,76,25.)
# labels = [left,right,top,bottom]
Map.drawparallels(parallels,labels=[True,False,False,False])
meridians = np.arange(0.,361.,60.)
Map.drawmeridians(meridians,labels=[False,False,False,True])

x, y = Map(lon, lat)

mapPlot = Map.pcolor(x, y, asia_area, cmap='Blues')
mapPlot.cmap.set_under('w')  # 设置底色
plt.show()
# Out:
# C:\Users\alzio\AppData\Local\Temp\ipykernel_17712\3002519533.py:17: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("Blues").copy()
#   mapPlot.cmap.set_under('w')  # 设置底色

# %%
non_emi = odiac_mean == 0.0
non_emi.sum()
# Out:
# 1703

# %%
longitude = np.linspace(-179.5, 179.5, 360)
latitude = np.linspace(-89.5, 89.5, 180)
lon, lat = np.meshgrid(longitude, latitude)

# %%
coordinates = np.array([lon[non_emi], lat[non_emi]]).T
coordinates
# Out:
# array([[138.5,  -7.5],
#        [138.5,  -6.5],
#        [138.5,  -5.5],
#        ...,
#        [ 95.5,  80.5],
#        [ 96.5,  80.5],
#        [ 97.5,  80.5]])

# %%
from pyproj import Geod
geod = Geod(ellps="WGS84")
length = coordinates.shape[0]

def distance(lon1, lat1, lon2, lat2):
    return geod.inv(lon1, lat1, lon2, lat2)[2]

# 寻找距离排放点源最近的非排放区坐标序列
def find_nearest(lon0, lat0):
    distances = distance(np.ones(length)*lon0, np.ones(length)*lat0, coordinates[:, 0], coordinates[:, 1])
    indices = np.argsort(distances)
    return indices

# %%
# 先求出对国内所有像元的最近非排放区下标序列
nearestSeq = np.full((180, 360, length), np.NaN)
for la in range(0, 180):
    for lo in range(0, 360):
        if china_area[la, lo] > 0.0:
            nearestSeq[la, lo] = find_nearest(lo-179.5, la-89.5)
            print(lo-179.5, la-89.5, la, lo)
# Out:
# 109.5 18.5 108 289
# 109.5 19.5 109 289
# 110.5 19.5 109 290
# 100.5 21.5 111 280
# 101.5 21.5 111 281
# 108.5 21.5 111 288
# 109.5 21.5 111 289
# 110.5 21.5 111 290
# 111.5 21.5 111 291
# 99.5 22.5 112 279
# 100.5 22.5 112 280
# 101.5 22.5 112 281
# 102.5 22.5 112 282
# 107.5 22.5 112 287
# 108.5 22.5 112 288
# 109.5 22.5 112 289
# 110.5 22.5 112 290
# 111.5 22.5 112 291
# 112.5 22.5 112 292
# 113.5 22.5 112 293
# 114.5 22.5 112 294
# 120.5 22.5 112 300
# 99.5 23.5 113 279
# 100.5 23.5 113 280
# 101.5 23.5 113 281
# 102.5 23.5 113 282
# 103.5 23.5 113 283
# 104.5 23.5 113 284
# 105.5 23.5 113 285
# 106.5 23.5 113 286
# 107.5 23.5 113 287
# 108.5 23.5 113 288
# 109.5 23.5 113 289
# 110.5 23.5 113 290
# 111.5 23.5 113 291
# 112.5 23.5 113 292
# 113.5 23.5 113 293
# 114.5 23.5 113 294
# 115.5 23.5 113 295
# 116.5 23.5 113 296
# 120.5 23.5 113 300
# 121.5 23.5 113 301
# 98.5 24.5 114 278
# 99.5 24.5 114 279
# 100.5 24.5 114 280
# 101.5 24.5 114 281
# 102.5 24.5 114 282
# 103.5 24.5 114 283
# 104.5 24.5 114 284
# 105.5 24.5 114 285
# 106.5 24.5 114 286
# 107.5 24.5 114 287
# 108.5 24.5 114 288
# 109.5 24.5 114 289
# 110.5 24.5 114 290
# 111.5 24.5 114 291
# 112.5 24.5 114 292
# 113.5 24.5 114 293
# 114.5 24.5 114 294
# 115.5 24.5 114 295
# 116.5 24.5 114 296
# 117.5 24.5 114 297
# 118.5 24.5 114 298
# 121.5 24.5 114 301
# 98.5 25.5 115 278
# 99.5 25.5 115 279
# 100.5 25.5 115 280
# 101.5 25.5 115 281
# 102.5 25.5 115 282
# 103.5 25.5 115 283
# 104.5 25.5 115 284
# 105.5 25.5 115 285
# 106.5 25.5 115 286
# 107.5 25.5 115 287
# 108.5 25.5 115 288
# 109.5 25.5 115 289
# 110.5 25.5 115 290
# 111.5 25.5 115 291
# 112.5 25.5 115 292
# 113.5 25.5 115 293
# 114.5 25.5 115 294
# 115.5 25.5 115 295
# 116.5 25.5 115 296
# 117.5 25.5 115 297
# 118.5 25.5 115 298
# 119.5 25.5 115 299
# 99.5 26.5 116 279
# 100.5 26.5 116 280
# 101.5 26.5 116 281
# 102.5 26.5 116 282
# 103.5 26.5 116 283
# 104.5 26.5 116 284
# 105.5 26.5 116 285
# 106.5 26.5 116 286
# 107.5 26.5 116 287
# 108.5 26.5 116 288
# 109.5 26.5 116 289
# 110.5 26.5 116 290
# 111.5 26.5 116 291
# 112.5 26.5 116 292
# 113.5 26.5 116 293
# 114.5 26.5 116 294
# 115.5 26.5 116 295
# 116.5 26.5 116 296
# 117.5 26.5 116 297
# 118.5 26.5 116 298
# 119.5 26.5 116 299
# 92.5 27.5 117 272
# 93.5 27.5 117 273
# 98.5 27.5 117 278
# 99.5 27.5 117 279
# 100.5 27.5 117 280
# 101.5 27.5 117 281
# 102.5 27.5 117 282
# 103.5 27.5 117 283
# 104.5 27.5 117 284
# 105.5 27.5 117 285
# 106.5 27.5 117 286
# 107.5 27.5 117 287
# 108.5 27.5 117 288
# 109.5 27.5 117 289
# 110.5 27.5 117 290
# 111.5 27.5 117 291
# 112.5 27.5 117 292
# 113.5 27.5 117 293
# 114.5 27.5 117 294
# 115.5 27.5 117 295
# 116.5 27.5 117 296
# 117.5 27.5 117 297
# 118.5 27.5 117 298
# 119.5 27.5 117 299
# 120.5 27.5 117 300
# 85.5 28.5 118 265
# 86.5 28.5 118 266
# 87.5 28.5 118 267
# 88.5 28.5 118 268
# 89.5 28.5 118 269
# 90.5 28.5 118 270
# 91.5 28.5 118 271
# 92.5 28.5 118 272
# 93.5 28.5 118 273
# 94.5 28.5 118 274
# 95.5 28.5 118 275
# 96.5 28.5 118 276
# 97.5 28.5 118 277
# 98.5 28.5 118 278
# 99.5 28.5 118 279
# 100.5 28.5 118 280
# 101.5 28.5 118 281
# 102.5 28.5 118 282
# 103.5 28.5 118 283
# 104.5 28.5 118 284
# 105.5 28.5 118 285
# 106.5 28.5 118 286
# 107.5 28.5 118 287
# 108.5 28.5 118 288
# 109.5 28.5 118 289
# 110.5 28.5 118 290
# 111.5 28.5 118 291
# 112.5 28.5 118 292
# 113.5 28.5 118 293
# 114.5 28.5 118 294
# 115.5 28.5 118 295
# 116.5 28.5 118 296
# 117.5 28.5 118 297
# 118.5 28.5 118 298
# 119.5 28.5 118 299
# 120.5 28.5 118 300
# 121.5 28.5 118 301
# 83.5 29.5 119 263
# 84.5 29.5 119 264
# 85.5 29.5 119 265
# 86.5 29.5 119 266
# 87.5 29.5 119 267
# 88.5 29.5 119 268
# 89.5 29.5 119 269
# 90.5 29.5 119 270
# 91.5 29.5 119 271
# 92.5 29.5 119 272
# 93.5 29.5 119 273
# 94.5 29.5 119 274
# 95.5 29.5 119 275
# 96.5 29.5 119 276
# 97.5 29.5 119 277
# 98.5 29.5 119 278
# 99.5 29.5 119 279
# 100.5 29.5 119 280
# 101.5 29.5 119 281
# 102.5 29.5 119 282
# 103.5 29.5 119 283
# 104.5 29.5 119 284
# 105.5 29.5 119 285
# 106.5 29.5 119 286
# 107.5 29.5 119 287
# 108.5 29.5 119 288
# 109.5 29.5 119 289
# 110.5 29.5 119 290
# 111.5 29.5 119 291
# 112.5 29.5 119 292
# 113.5 29.5 119 293
# 114.5 29.5 119 294
# 115.5 29.5 119 295
# 116.5 29.5 119 296
# 117.5 29.5 119 297
# 118.5 29.5 119 298
# 119.5 29.5 119 299
# 120.5 29.5 119 300
# 121.5 29.5 119 301
# 80.5 30.5 120 260
# 81.5 30.5 120 261
# 82.5 30.5 120 262
# 83.5 30.5 120 263
# 84.5 30.5 120 264
# 85.5 30.5 120 265
# 86.5 30.5 120 266
# 87.5 30.5 120 267
# 88.5 30.5 120 268
# 89.5 30.5 120 269
# 90.5 30.5 120 270
# 91.5 30.5 120 271
# 92.5 30.5 120 272
# 93.5 30.5 120 273
# 94.5 30.5 120 274
# 95.5 30.5 120 275
# 96.5 30.5 120 276
# 97.5 30.5 120 277
# 98.5 30.5 120 278
# 99.5 30.5 120 279
# 100.5 30.5 120 280
# 101.5 30.5 120 281
# 102.5 30.5 120 282
# 103.5 30.5 120 283
# 104.5 30.5 120 284
# 105.5 30.5 120 285
# 106.5 30.5 120 286
# 107.5 30.5 120 287
# 108.5 30.5 120 288
# 109.5 30.5 120 289
# 110.5 30.5 120 290
# 111.5 30.5 120 291
# 112.5 30.5 120 292
# 113.5 30.5 120 293
# 114.5 30.5 120 294
# 115.5 30.5 120 295
# 116.5 30.5 120 296
# 117.5 30.5 120 297
# 118.5 30.5 120 298
# 119.5 30.5 120 299
# 120.5 30.5 120 300
# 121.5 30.5 120 301
# 79.5 31.5 121 259
# 80.5 31.5 121 260
# 81.5 31.5 121 261
# 82.5 31.5 121 262
# 83.5 31.5 121 263
# 84.5 31.5 121 264
# 85.5 31.5 121 265
# 86.5 31.5 121 266
# 87.5 31.5 121 267
# 88.5 31.5 121 268
# 89.5 31.5 121 269
# 90.5 31.5 121 270
# 91.5 31.5 121 271
# 92.5 31.5 121 272
# 93.5 31.5 121 273
# 94.5 31.5 121 274
# 95.5 31.5 121 275
# 96.5 31.5 121 276
# 97.5 31.5 121 277
# 98.5 31.5 121 278
# 99.5 31.5 121 279
# 100.5 31.5 121 280
# 101.5 31.5 121 281
# 102.5 31.5 121 282
# 103.5 31.5 121 283
# 104.5 31.5 121 284
# 105.5 31.5 121 285
# 106.5 31.5 121 286
# 107.5 31.5 121 287
# 108.5 31.5 121 288
# 109.5 31.5 121 289
# 110.5 31.5 121 290
# 111.5 31.5 121 291
# 112.5 31.5 121 292
# 113.5 31.5 121 293
# 114.5 31.5 121 294
# 115.5 31.5 121 295
# 116.5 31.5 121 296
# 117.5 31.5 121 297
# 118.5 31.5 121 298
# 119.5 31.5 121 299
# 120.5 31.5 121 300
# 121.5 31.5 121 301
# 79.5 32.5 122 259
# 80.5 32.5 122 260
# 81.5 32.5 122 261
# 82.5 32.5 122 262
# 83.5 32.5 122 263
# 84.5 32.5 122 264
# 85.5 32.5 122 265
# 86.5 32.5 122 266
# 87.5 32.5 122 267
# 88.5 32.5 122 268
# 89.5 32.5 122 269
# 90.5 32.5 122 270
# 91.5 32.5 122 271
# 92.5 32.5 122 272
# 93.5 32.5 122 273
# 94.5 32.5 122 274
# 95.5 32.5 122 275
# 96.5 32.5 122 276
# 97.5 32.5 122 277
# 98.5 32.5 122 278
# 99.5 32.5 122 279
# 100.5 32.5 122 280
# 101.5 32.5 122 281
# 102.5 32.5 122 282
# 103.5 32.5 122 283
# 104.5 32.5 122 284
# 105.5 32.5 122 285
# 106.5 32.5 122 286
# 107.5 32.5 122 287
# 108.5 32.5 122 288
# 109.5 32.5 122 289
# 110.5 32.5 122 290
# 111.5 32.5 122 291
# 112.5 32.5 122 292
# 113.5 32.5 122 293
# 114.5 32.5 122 294
# 115.5 32.5 122 295
# 116.5 32.5 122 296
# 117.5 32.5 122 297
# 118.5 32.5 122 298
# 119.5 32.5 122 299
# 120.5 32.5 122 300
# 79.5 33.5 123 259
# 80.5 33.5 123 260
# 81.5 33.5 123 261
# 82.5 33.5 123 262
# 83.5 33.5 123 263
# 84.5 33.5 123 264
# 85.5 33.5 123 265
# 86.5 33.5 123 266
# 87.5 33.5 123 267
# 88.5 33.5 123 268
# 89.5 33.5 123 269
# 90.5 33.5 123 270
# 91.5 33.5 123 271
# 92.5 33.5 123 272
# 93.5 33.5 123 273
# 94.5 33.5 123 274
# 95.5 33.5 123 275
# 96.5 33.5 123 276
# 97.5 33.5 123 277
# 98.5 33.5 123 278
# 99.5 33.5 123 279
# 100.5 33.5 123 280
# 101.5 33.5 123 281
# 102.5 33.5 123 282
# 103.5 33.5 123 283
# 104.5 33.5 123 284
# 105.5 33.5 123 285
# 106.5 33.5 123 286
# 107.5 33.5 123 287
# 108.5 33.5 123 288
# 109.5 33.5 123 289
# 110.5 33.5 123 290
# 111.5 33.5 123 291
# 112.5 33.5 123 292
# 113.5 33.5 123 293
# 114.5 33.5 123 294
# 115.5 33.5 123 295
# 116.5 33.5 123 296
# 117.5 33.5 123 297
# 118.5 33.5 123 298
# 119.5 33.5 123 299
# 120.5 33.5 123 300
# 78.5 34.5 124 258
# 79.5 34.5 124 259
# 80.5 34.5 124 260
# 81.5 34.5 124 261
# 82.5 34.5 124 262
# 83.5 34.5 124 263
# 84.5 34.5 124 264
# 85.5 34.5 124 265
# 86.5 34.5 124 266
# 87.5 34.5 124 267
# 88.5 34.5 124 268
# 89.5 34.5 124 269
# 90.5 34.5 124 270
# 91.5 34.5 124 271
# 92.5 34.5 124 272
# 93.5 34.5 124 273
# 94.5 34.5 124 274
# 95.5 34.5 124 275
# 96.5 34.5 124 276
# 97.5 34.5 124 277
# 98.5 34.5 124 278
# 99.5 34.5 124 279
# 100.5 34.5 124 280
# 101.5 34.5 124 281
# 102.5 34.5 124 282
# 103.5 34.5 124 283
# 104.5 34.5 124 284
# 105.5 34.5 124 285
# 106.5 34.5 124 286
# 107.5 34.5 124 287
# 108.5 34.5 124 288
# 109.5 34.5 124 289
# 110.5 34.5 124 290
# 111.5 34.5 124 291
# 112.5 34.5 124 292
# 113.5 34.5 124 293
# 114.5 34.5 124 294
# 115.5 34.5 124 295
# 116.5 34.5 124 296
# 117.5 34.5 124 297
# 118.5 34.5 124 298
# 119.5 34.5 124 299
# 77.5 35.5 125 257
# 78.5 35.5 125 258
# 79.5 35.5 125 259
# 80.5 35.5 125 260
# 81.5 35.5 125 261
# 82.5 35.5 125 262
# 83.5 35.5 125 263
# 84.5 35.5 125 264
# 85.5 35.5 125 265
# 86.5 35.5 125 266
# 87.5 35.5 125 267
# 88.5 35.5 125 268
# 89.5 35.5 125 269
# 90.5 35.5 125 270
# 91.5 35.5 125 271
# 92.5 35.5 125 272
# 93.5 35.5 125 273
# 94.5 35.5 125 274
# 95.5 35.5 125 275
# 96.5 35.5 125 276
# 97.5 35.5 125 277
# 98.5 35.5 125 278
# 99.5 35.5 125 279
# 100.5 35.5 125 280
# 101.5 35.5 125 281
# 102.5 35.5 125 282
# 103.5 35.5 125 283
# 104.5 35.5 125 284
# 105.5 35.5 125 285
# 106.5 35.5 125 286
# 107.5 35.5 125 287
# 108.5 35.5 125 288
# 109.5 35.5 125 289
# 110.5 35.5 125 290
# 111.5 35.5 125 291
# 112.5 35.5 125 292
# 113.5 35.5 125 293
# 114.5 35.5 125 294
# 115.5 35.5 125 295
# 116.5 35.5 125 296
# 117.5 35.5 125 297
# 118.5 35.5 125 298
# 119.5 35.5 125 299
# 76.5 36.5 126 256
# 77.5 36.5 126 257
# 78.5 36.5 126 258
# 79.5 36.5 126 259
# 80.5 36.5 126 260
# 81.5 36.5 126 261
# 82.5 36.5 126 262
# 83.5 36.5 126 263
# 84.5 36.5 126 264
# 85.5 36.5 126 265
# 86.5 36.5 126 266
# 87.5 36.5 126 267
# 88.5 36.5 126 268
# 89.5 36.5 126 269
# 90.5 36.5 126 270
# 91.5 36.5 126 271
# 92.5 36.5 126 272
# 93.5 36.5 126 273
# 94.5 36.5 126 274
# 95.5 36.5 126 275
# 96.5 36.5 126 276
# 97.5 36.5 126 277
# 98.5 36.5 126 278
# 99.5 36.5 126 279
# 100.5 36.5 126 280
# 101.5 36.5 126 281
# 102.5 36.5 126 282
# 103.5 36.5 126 283
# 104.5 36.5 126 284
# 105.5 36.5 126 285
# 106.5 36.5 126 286
# 107.5 36.5 126 287
# 108.5 36.5 126 288
# 109.5 36.5 126 289
# 110.5 36.5 126 290
# 111.5 36.5 126 291
# 112.5 36.5 126 292
# 113.5 36.5 126 293
# 114.5 36.5 126 294
# 115.5 36.5 126 295
# 116.5 36.5 126 296
# 117.5 36.5 126 297
# 118.5 36.5 126 298
# 119.5 36.5 126 299
# 120.5 36.5 126 300
# 75.5 37.5 127 255
# 76.5 37.5 127 256
# 77.5 37.5 127 257
# 78.5 37.5 127 258
# 79.5 37.5 127 259
# 80.5 37.5 127 260
# 81.5 37.5 127 261
# 82.5 37.5 127 262
# 83.5 37.5 127 263
# 84.5 37.5 127 264
# 85.5 37.5 127 265
# 86.5 37.5 127 266
# 87.5 37.5 127 267
# 88.5 37.5 127 268
# 89.5 37.5 127 269
# 90.5 37.5 127 270
# 91.5 37.5 127 271
# 92.5 37.5 127 272
# 93.5 37.5 127 273
# 94.5 37.5 127 274
# 95.5 37.5 127 275
# 96.5 37.5 127 276
# 97.5 37.5 127 277
# 98.5 37.5 127 278
# 99.5 37.5 127 279
# 100.5 37.5 127 280
# 101.5 37.5 127 281
# 102.5 37.5 127 282
# 103.5 37.5 127 283
# 104.5 37.5 127 284
# 105.5 37.5 127 285
# 106.5 37.5 127 286
# 107.5 37.5 127 287
# 108.5 37.5 127 288
# 109.5 37.5 127 289
# 110.5 37.5 127 290
# 111.5 37.5 127 291
# 112.5 37.5 127 292
# 113.5 37.5 127 293
# 114.5 37.5 127 294
# 115.5 37.5 127 295
# 116.5 37.5 127 296
# 117.5 37.5 127 297
# 118.5 37.5 127 298
# 120.5 37.5 127 300
# 121.5 37.5 127 301
# 74.5 38.5 128 254
# 75.5 38.5 128 255
# 76.5 38.5 128 256
# 77.5 38.5 128 257
# 78.5 38.5 128 258
# 79.5 38.5 128 259
# 80.5 38.5 128 260
# 81.5 38.5 128 261
# 82.5 38.5 128 262
# 83.5 38.5 128 263
# 84.5 38.5 128 264
# 85.5 38.5 128 265
# 86.5 38.5 128 266
# 87.5 38.5 128 267
# 88.5 38.5 128 268
# 89.5 38.5 128 269
# 90.5 38.5 128 270
# 91.5 38.5 128 271
# 92.5 38.5 128 272
# 93.5 38.5 128 273
# 94.5 38.5 128 274
# 95.5 38.5 128 275
# 96.5 38.5 128 276
# 97.5 38.5 128 277
# 98.5 38.5 128 278
# 99.5 38.5 128 279
# 100.5 38.5 128 280
# 101.5 38.5 128 281
# 102.5 38.5 128 282
# 103.5 38.5 128 283
# 104.5 38.5 128 284
# 105.5 38.5 128 285
# 106.5 38.5 128 286
# 107.5 38.5 128 287
# 108.5 38.5 128 288
# 109.5 38.5 128 289
# 110.5 38.5 128 290
# 111.5 38.5 128 291
# 112.5 38.5 128 292
# 113.5 38.5 128 293
# 114.5 38.5 128 294
# 115.5 38.5 128 295
# 116.5 38.5 128 296
# 117.5 38.5 128 297
# 74.5 39.5 129 254
# 75.5 39.5 129 255
# 76.5 39.5 129 256
# 77.5 39.5 129 257
# 78.5 39.5 129 258
# 79.5 39.5 129 259
# 80.5 39.5 129 260
# 81.5 39.5 129 261
# 82.5 39.5 129 262
# 83.5 39.5 129 263
# 84.5 39.5 129 264
# 85.5 39.5 129 265
# 86.5 39.5 129 266
# 87.5 39.5 129 267
# 88.5 39.5 129 268
# 89.5 39.5 129 269
# 90.5 39.5 129 270
# 91.5 39.5 129 271
# 92.5 39.5 129 272
# 93.5 39.5 129 273
# 94.5 39.5 129 274
# 95.5 39.5 129 275
# 96.5 39.5 129 276
# 97.5 39.5 129 277
# 98.5 39.5 129 278
# 99.5 39.5 129 279
# 100.5 39.5 129 280
# 101.5 39.5 129 281
# 102.5 39.5 129 282
# 103.5 39.5 129 283
# 104.5 39.5 129 284
# 105.5 39.5 129 285
# 106.5 39.5 129 286
# 107.5 39.5 129 287
# 108.5 39.5 129 288
# 109.5 39.5 129 289
# 110.5 39.5 129 290
# 111.5 39.5 129 291
# 112.5 39.5 129 292
# 113.5 39.5 129 293
# 114.5 39.5 129 294
# 115.5 39.5 129 295
# 116.5 39.5 129 296
# 117.5 39.5 129 297
# 118.5 39.5 129 298
# 121.5 39.5 129 301
# 122.5 39.5 129 302
# 75.5 40.5 130 255
# 76.5 40.5 130 256
# 77.5 40.5 130 257
# 78.5 40.5 130 258
# 79.5 40.5 130 259
# 80.5 40.5 130 260
# 81.5 40.5 130 261
# 82.5 40.5 130 262
# 83.5 40.5 130 263
# 84.5 40.5 130 264
# 85.5 40.5 130 265
# 86.5 40.5 130 266
# 87.5 40.5 130 267
# 88.5 40.5 130 268
# 89.5 40.5 130 269
# 90.5 40.5 130 270
# 91.5 40.5 130 271
# 92.5 40.5 130 272
# 93.5 40.5 130 273
# 94.5 40.5 130 274
# 95.5 40.5 130 275
# 96.5 40.5 130 276
# 97.5 40.5 130 277
# 98.5 40.5 130 278
# 99.5 40.5 130 279
# 100.5 40.5 130 280
# 101.5 40.5 130 281
# 102.5 40.5 130 282
# 103.5 40.5 130 283
# 104.5 40.5 130 284
# 105.5 40.5 130 285
# 106.5 40.5 130 286
# 107.5 40.5 130 287
# 108.5 40.5 130 288
# 109.5 40.5 130 289
# 110.5 40.5 130 290
# 111.5 40.5 130 291
# 112.5 40.5 130 292
# 113.5 40.5 130 293
# 114.5 40.5 130 294
# 115.5 40.5 130 295
# 116.5 40.5 130 296
# 117.5 40.5 130 297
# 118.5 40.5 130 298
# 119.5 40.5 130 299
# 120.5 40.5 130 300
# 122.5 40.5 130 302
# 123.5 40.5 130 303
# 124.5 40.5 130 304
# 78.5 41.5 131 258
# 79.5 41.5 131 259
# 80.5 41.5 131 260
# 81.5 41.5 131 261
# 82.5 41.5 131 262
# 83.5 41.5 131 263
# 84.5 41.5 131 264
# 85.5 41.5 131 265
# 86.5 41.5 131 266
# 87.5 41.5 131 267
# 88.5 41.5 131 268
# 89.5 41.5 131 269
# 90.5 41.5 131 270
# 91.5 41.5 131 271
# 92.5 41.5 131 272
# 93.5 41.5 131 273
# 94.5 41.5 131 274
# 95.5 41.5 131 275
# 96.5 41.5 131 276
# 97.5 41.5 131 277
# 98.5 41.5 131 278
# 99.5 41.5 131 279
# 100.5 41.5 131 280
# 101.5 41.5 131 281
# 102.5 41.5 131 282
# 103.5 41.5 131 283
# 104.5 41.5 131 284
# 105.5 41.5 131 285
# 106.5 41.5 131 286
# 107.5 41.5 131 287
# 108.5 41.5 131 288
# 109.5 41.5 131 289
# 110.5 41.5 131 290
# 111.5 41.5 131 291
# 112.5 41.5 131 292
# 113.5 41.5 131 293
# 114.5 41.5 131 294
# 115.5 41.5 131 295
# 116.5 41.5 131 296
# 117.5 41.5 131 297
# 118.5 41.5 131 298
# 119.5 41.5 131 299
# 120.5 41.5 131 300
# 121.5 41.5 131 301
# 122.5 41.5 131 302
# 123.5 41.5 131 303
# 124.5 41.5 131 304
# 125.5 41.5 131 305
# 126.5 41.5 131 306
# 127.5 41.5 131 307
# 80.5 42.5 132 260
# 81.5 42.5 132 261
# 82.5 42.5 132 262
# 83.5 42.5 132 263
# 84.5 42.5 132 264
# 85.5 42.5 132 265
# 86.5 42.5 132 266
# 87.5 42.5 132 267
# 88.5 42.5 132 268
# 89.5 42.5 132 269
# 90.5 42.5 132 270
# 91.5 42.5 132 271
# 92.5 42.5 132 272
# 93.5 42.5 132 273
# 94.5 42.5 132 274
# 95.5 42.5 132 275
# 96.5 42.5 132 276
# 97.5 42.5 132 277
# 98.5 42.5 132 278
# 99.5 42.5 132 279
# 100.5 42.5 132 280
# 101.5 42.5 132 281
# 108.5 42.5 132 288
# 109.5 42.5 132 289
# 110.5 42.5 132 290
# 111.5 42.5 132 291
# 112.5 42.5 132 292
# 113.5 42.5 132 293
# 114.5 42.5 132 294
# 115.5 42.5 132 295
# 116.5 42.5 132 296
# 117.5 42.5 132 297
# 118.5 42.5 132 298
# 119.5 42.5 132 299
# 120.5 42.5 132 300
# 121.5 42.5 132 301
# 122.5 42.5 132 302
# 123.5 42.5 132 303
# 124.5 42.5 132 304
# 125.5 42.5 132 305
# 126.5 42.5 132 306
# 127.5 42.5 132 307
# 128.5 42.5 132 308
# 129.5 42.5 132 309
# 81.5 43.5 133 261
# 82.5 43.5 133 262
# 83.5 43.5 133 263
# 84.5 43.5 133 264
# 85.5 43.5 133 265
# 86.5 43.5 133 266
# 87.5 43.5 133 267
# 88.5 43.5 133 268
# 89.5 43.5 133 269
# 90.5 43.5 133 270
# 91.5 43.5 133 271
# 92.5 43.5 133 272
# 93.5 43.5 133 273
# 94.5 43.5 133 274
# 95.5 43.5 133 275
# 111.5 43.5 133 291
# 112.5 43.5 133 292
# 113.5 43.5 133 293
# 114.5 43.5 133 294
# 115.5 43.5 133 295
# 116.5 43.5 133 296
# 117.5 43.5 133 297
# 118.5 43.5 133 298
# 119.5 43.5 133 299
# 120.5 43.5 133 300
# 121.5 43.5 133 301
# 122.5 43.5 133 302
# 123.5 43.5 133 303
# 124.5 43.5 133 304
# 125.5 43.5 133 305
# 126.5 43.5 133 306
# 127.5 43.5 133 307
# 128.5 43.5 133 308
# 129.5 43.5 133 309
# 130.5 43.5 133 310
# 80.5 44.5 134 260
# 81.5 44.5 134 261
# 82.5 44.5 134 262
# 83.5 44.5 134 263
# 84.5 44.5 134 264
# 85.5 44.5 134 265
# 86.5 44.5 134 266
# 87.5 44.5 134 267
# 88.5 44.5 134 268
# 89.5 44.5 134 269
# 90.5 44.5 134 270
# 91.5 44.5 134 271
# 92.5 44.5 134 272
# 93.5 44.5 134 273
# 94.5 44.5 134 274
# 111.5 44.5 134 291
# 112.5 44.5 134 292
# 113.5 44.5 134 293
# 114.5 44.5 134 294
# 115.5 44.5 134 295
# 116.5 44.5 134 296
# 117.5 44.5 134 297
# 118.5 44.5 134 298
# 119.5 44.5 134 299
# 120.5 44.5 134 300
# 121.5 44.5 134 301
# 122.5 44.5 134 302
# 123.5 44.5 134 303
# 124.5 44.5 134 304
# 125.5 44.5 134 305
# 126.5 44.5 134 306
# 127.5 44.5 134 307
# 128.5 44.5 134 308
# 129.5 44.5 134 309
# 130.5 44.5 134 310
# 82.5 45.5 135 262
# 83.5 45.5 135 263
# 84.5 45.5 135 264
# 85.5 45.5 135 265
# 86.5 45.5 135 266
# 87.5 45.5 135 267
# 88.5 45.5 135 268
# 89.5 45.5 135 269
# 90.5 45.5 135 270
# 115.5 45.5 135 295
# 116.5 45.5 135 296
# 117.5 45.5 135 297
# 118.5 45.5 135 298
# 119.5 45.5 135 299
# 120.5 45.5 135 300
# 121.5 45.5 135 301
# 122.5 45.5 135 302
# 123.5 45.5 135 303
# 124.5 45.5 135 304
# 125.5 45.5 135 305
# 126.5 45.5 135 306
# 127.5 45.5 135 307
# 128.5 45.5 135 308
# 129.5 45.5 135 309
# 130.5 45.5 135 310
# 131.5 45.5 135 311
# 132.5 45.5 135 312
# 83.5 46.5 136 263
# 84.5 46.5 136 264
# 85.5 46.5 136 265
# 86.5 46.5 136 266
# 87.5 46.5 136 267
# 88.5 46.5 136 268
# 89.5 46.5 136 269
# 90.5 46.5 136 270
# 117.5 46.5 136 297
# 118.5 46.5 136 298
# 119.5 46.5 136 299
# 120.5 46.5 136 300
# 121.5 46.5 136 301
# 122.5 46.5 136 302
# 123.5 46.5 136 303
# 124.5 46.5 136 304
# 125.5 46.5 136 305
# 126.5 46.5 136 306
# 127.5 46.5 136 307
# 128.5 46.5 136 308
# 129.5 46.5 136 309
# 130.5 46.5 136 310
# 131.5 46.5 136 311
# 132.5 46.5 136 312
# 133.5 46.5 136 313
# 85.5 47.5 137 265
# 86.5 47.5 137 266
# 87.5 47.5 137 267
# 88.5 47.5 137 268
# 89.5 47.5 137 269
# 119.5 47.5 137 299
# 120.5 47.5 137 300
# 121.5 47.5 137 301
# 122.5 47.5 137 302
# 123.5 47.5 137 303
# 124.5 47.5 137 304
# 125.5 47.5 137 305
# 126.5 47.5 137 306
# 127.5 47.5 137 307
# 128.5 47.5 137 308
# 129.5 47.5 137 309
# 130.5 47.5 137 310
# 131.5 47.5 137 311
# 132.5 47.5 137 312
# 133.5 47.5 137 313
# 134.5 47.5 137 314
# 86.5 48.5 138 266
# 87.5 48.5 138 267
# 116.5 48.5 138 296
# 117.5 48.5 138 297
# 118.5 48.5 138 298
# 119.5 48.5 138 299
# 120.5 48.5 138 300
# 121.5 48.5 138 301
# 122.5 48.5 138 302
# 123.5 48.5 138 303
# 124.5 48.5 138 304
# 125.5 48.5 138 305
# 126.5 48.5 138 306
# 127.5 48.5 138 307
# 128.5 48.5 138 308
# 129.5 48.5 138 309
# 130.5 48.5 138 310
# 116.5 49.5 139 296
# 117.5 49.5 139 297
# 118.5 49.5 139 298
# 119.5 49.5 139 299
# 120.5 49.5 139 300
# 121.5 49.5 139 301
# 122.5 49.5 139 302
# 123.5 49.5 139 303
# 124.5 49.5 139 304
# 125.5 49.5 139 305
# 126.5 49.5 139 306
# 127.5 49.5 139 307
# 128.5 49.5 139 308
# 119.5 50.5 140 299
# 120.5 50.5 140 300
# 121.5 50.5 140 301
# 122.5 50.5 140 302
# 123.5 50.5 140 303
# 124.5 50.5 140 304
# 125.5 50.5 140 305
# 126.5 50.5 140 306
# 120.5 51.5 141 300
# 121.5 51.5 141 301
# 122.5 51.5 141 302
# 123.5 51.5 141 303
# 124.5 51.5 141 304
# 125.5 51.5 141 305
# 126.5 51.5 141 306
# 120.5 52.5 142 300
# 121.5 52.5 142 301
# 122.5 52.5 142 302
# 123.5 52.5 142 303
# 124.5 52.5 142 304
# 125.5 52.5 142 305
# 122.5 53.5 143 302
# 123.5 53.5 143 303

# %%
# 从MappingXCO2月份版做，先做5、10、15三个版本
import os
from copy import deepcopy
def dxco2_gen(m):
    inPath = "H:\\XCO2\\MappingXCO2\\MappingXCO2_month_npy"
    outPath = f"H:\\XCO2\\MappingXCO2\\MappingXCO2_NNG_global_china_{m}_month"
    if not os.path.exists(outPath):
        os.mkdir(outPath)
    temp_nearest = deepcopy(nearestSeq[:, :, :m])  # 现在代表在序列中的下标
    for year in range(2010, 2021):
        for month in range(1, 13):
            bkg = np.full((180, 360), np.NaN)
            xco2 = np.load(inPath + "\\" + f"MappingXCO2_{year}{str(month).zfill(2)}.npy")
            non_emi_xco2 = xco2[non_emi]  # 提取：长度length非排放区XCO2
            for la in range(180):
                for lo in range(360):
                    if china_area[la, lo] > 0.0:
                        bkg[la, lo] = np.nanmean(non_emi_xco2[temp_nearest[la, lo].astype(int)])  # 求背景值
            dxco2 = xco2 - bkg
            np.save(outPath + "\\" + f"MappingXCO2_{year}{str(month).zfill(2)}.npy", dxco2)
            print(f"NGG_{m}  MappingXCO2_{year}{str(month).zfill(2)}.npy  Succeed.")

dxco2_gen(5)
# Out:
# NGG_5  MappingXCO2_201001.npy  Succeed.
# NGG_5  MappingXCO2_201002.npy  Succeed.
# NGG_5  MappingXCO2_201003.npy  Succeed.
# NGG_5  MappingXCO2_201004.npy  Succeed.
# NGG_5  MappingXCO2_201005.npy  Succeed.
# NGG_5  MappingXCO2_201006.npy  Succeed.
# NGG_5  MappingXCO2_201007.npy  Succeed.
# NGG_5  MappingXCO2_201008.npy  Succeed.
# NGG_5  MappingXCO2_201009.npy  Succeed.
# NGG_5  MappingXCO2_201010.npy  Succeed.
# NGG_5  MappingXCO2_201011.npy  Succeed.
# NGG_5  MappingXCO2_201012.npy  Succeed.
# NGG_5  MappingXCO2_201101.npy  Succeed.
# NGG_5  MappingXCO2_201102.npy  Succeed.
# NGG_5  MappingXCO2_201103.npy  Succeed.
# NGG_5  MappingXCO2_201104.npy  Succeed.
# NGG_5  MappingXCO2_201105.npy  Succeed.
# NGG_5  MappingXCO2_201106.npy  Succeed.
# NGG_5  MappingXCO2_201107.npy  Succeed.
# NGG_5  MappingXCO2_201108.npy  Succeed.
# NGG_5  MappingXCO2_201109.npy  Succeed.
# NGG_5  MappingXCO2_201110.npy  Succeed.
# NGG_5  MappingXCO2_201111.npy  Succeed.
# NGG_5  MappingXCO2_201112.npy  Succeed.
# NGG_5  MappingXCO2_201201.npy  Succeed.
# NGG_5  MappingXCO2_201202.npy  Succeed.
# NGG_5  MappingXCO2_201203.npy  Succeed.
# NGG_5  MappingXCO2_201204.npy  Succeed.
# NGG_5  MappingXCO2_201205.npy  Succeed.
# NGG_5  MappingXCO2_201206.npy  Succeed.
# NGG_5  MappingXCO2_201207.npy  Succeed.
# NGG_5  MappingXCO2_201208.npy  Succeed.
# NGG_5  MappingXCO2_201209.npy  Succeed.
# NGG_5  MappingXCO2_201210.npy  Succeed.
# NGG_5  MappingXCO2_201211.npy  Succeed.
# NGG_5  MappingXCO2_201212.npy  Succeed.
# NGG_5  MappingXCO2_201301.npy  Succeed.
# NGG_5  MappingXCO2_201302.npy  Succeed.
# NGG_5  MappingXCO2_201303.npy  Succeed.
# NGG_5  MappingXCO2_201304.npy  Succeed.
# NGG_5  MappingXCO2_201305.npy  Succeed.
# NGG_5  MappingXCO2_201306.npy  Succeed.
# NGG_5  MappingXCO2_201307.npy  Succeed.
# NGG_5  MappingXCO2_201308.npy  Succeed.
# NGG_5  MappingXCO2_201309.npy  Succeed.
# NGG_5  MappingXCO2_201310.npy  Succeed.
# NGG_5  MappingXCO2_201311.npy  Succeed.
# NGG_5  MappingXCO2_201312.npy  Succeed.
# NGG_5  MappingXCO2_201401.npy  Succeed.
# NGG_5  MappingXCO2_201402.npy  Succeed.
# NGG_5  MappingXCO2_201403.npy  Succeed.
# NGG_5  MappingXCO2_201404.npy  Succeed.
# NGG_5  MappingXCO2_201405.npy  Succeed.
# NGG_5  MappingXCO2_201406.npy  Succeed.
# NGG_5  MappingXCO2_201407.npy  Succeed.
# NGG_5  MappingXCO2_201408.npy  Succeed.
# NGG_5  MappingXCO2_201409.npy  Succeed.
# NGG_5  MappingXCO2_201410.npy  Succeed.
# NGG_5  MappingXCO2_201411.npy  Succeed.
# NGG_5  MappingXCO2_201412.npy  Succeed.
# NGG_5  MappingXCO2_201501.npy  Succeed.
# NGG_5  MappingXCO2_201502.npy  Succeed.
# NGG_5  MappingXCO2_201503.npy  Succeed.
# NGG_5  MappingXCO2_201504.npy  Succeed.
# NGG_5  MappingXCO2_201505.npy  Succeed.
# NGG_5  MappingXCO2_201506.npy  Succeed.
# NGG_5  MappingXCO2_201507.npy  Succeed.
# NGG_5  MappingXCO2_201508.npy  Succeed.
# NGG_5  MappingXCO2_201509.npy  Succeed.
# NGG_5  MappingXCO2_201510.npy  Succeed.
# NGG_5  MappingXCO2_201511.npy  Succeed.
# NGG_5  MappingXCO2_201512.npy  Succeed.
# NGG_5  MappingXCO2_201601.npy  Succeed.
# NGG_5  MappingXCO2_201602.npy  Succeed.
# NGG_5  MappingXCO2_201603.npy  Succeed.
# NGG_5  MappingXCO2_201604.npy  Succeed.
# NGG_5  MappingXCO2_201605.npy  Succeed.
# NGG_5  MappingXCO2_201606.npy  Succeed.
# NGG_5  MappingXCO2_201607.npy  Succeed.
# NGG_5  MappingXCO2_201608.npy  Succeed.
# NGG_5  MappingXCO2_201609.npy  Succeed.
# NGG_5  MappingXCO2_201610.npy  Succeed.
# NGG_5  MappingXCO2_201611.npy  Succeed.
# NGG_5  MappingXCO2_201612.npy  Succeed.
# NGG_5  MappingXCO2_201701.npy  Succeed.
# NGG_5  MappingXCO2_201702.npy  Succeed.
# NGG_5  MappingXCO2_201703.npy  Succeed.
# NGG_5  MappingXCO2_201704.npy  Succeed.
# NGG_5  MappingXCO2_201705.npy  Succeed.
# NGG_5  MappingXCO2_201706.npy  Succeed.
# NGG_5  MappingXCO2_201707.npy  Succeed.
# NGG_5  MappingXCO2_201708.npy  Succeed.
# NGG_5  MappingXCO2_201709.npy  Succeed.
# NGG_5  MappingXCO2_201710.npy  Succeed.
# NGG_5  MappingXCO2_201711.npy  Succeed.
# NGG_5  MappingXCO2_201712.npy  Succeed.
# NGG_5  MappingXCO2_201801.npy  Succeed.
# NGG_5  MappingXCO2_201802.npy  Succeed.
# NGG_5  MappingXCO2_201803.npy  Succeed.
# NGG_5  MappingXCO2_201804.npy  Succeed.
# NGG_5  MappingXCO2_201805.npy  Succeed.
# NGG_5  MappingXCO2_201806.npy  Succeed.
# NGG_5  MappingXCO2_201807.npy  Succeed.
# NGG_5  MappingXCO2_201808.npy  Succeed.
# NGG_5  MappingXCO2_201809.npy  Succeed.
# NGG_5  MappingXCO2_201810.npy  Succeed.
# NGG_5  MappingXCO2_201811.npy  Succeed.
# NGG_5  MappingXCO2_201812.npy  Succeed.
# NGG_5  MappingXCO2_201901.npy  Succeed.
# NGG_5  MappingXCO2_201902.npy  Succeed.
# NGG_5  MappingXCO2_201903.npy  Succeed.
# NGG_5  MappingXCO2_201904.npy  Succeed.
# NGG_5  MappingXCO2_201905.npy  Succeed.
# NGG_5  MappingXCO2_201906.npy  Succeed.
# NGG_5  MappingXCO2_201907.npy  Succeed.
# NGG_5  MappingXCO2_201908.npy  Succeed.
# NGG_5  MappingXCO2_201909.npy  Succeed.
# NGG_5  MappingXCO2_201910.npy  Succeed.
# NGG_5  MappingXCO2_201911.npy  Succeed.
# NGG_5  MappingXCO2_201912.npy  Succeed.
# NGG_5  MappingXCO2_202001.npy  Succeed.
# NGG_5  MappingXCO2_202002.npy  Succeed.
# NGG_5  MappingXCO2_202003.npy  Succeed.
# NGG_5  MappingXCO2_202004.npy  Succeed.
# NGG_5  MappingXCO2_202005.npy  Succeed.
# NGG_5  MappingXCO2_202006.npy  Succeed.
# NGG_5  MappingXCO2_202007.npy  Succeed.
# NGG_5  MappingXCO2_202008.npy  Succeed.
# NGG_5  MappingXCO2_202009.npy  Succeed.
# NGG_5  MappingXCO2_202010.npy  Succeed.
# NGG_5  MappingXCO2_202011.npy  Succeed.
# NGG_5  MappingXCO2_202012.npy  Succeed.

# %%
# 生成年
def dxco2_year_gen(m):
    inPath = f"H:\\XCO2\\MappingXCO2\\MappingXCO2_NNG_global_china_{m}_month"
    outPath = f"H:\\XCO2\\MappingXCO2\\MappingXCO2_NNG_global_china_{m}_year"
    if not os.path.exists(outPath):
        os.mkdir(outPath)
    for year in range(2010, 2021):
        data_months = np.array([np.load(inPath + "\\" + f"MappingXCO2_{year}{str(month).zfill(2)}.npy") for month in range(1, 13)])
        data_year = data_months.mean(axis=0)
        np.save(outPath + "\\" + f"MappingXCO2_{year}", data_year)
        print(f"NNG_{m}  {year}  Succeed.")

# %%
dxco2_year_gen(5)
# Out:
# NNG_5  2010  Succeed.
# NNG_5  2011  Succeed.
# NNG_5  2012  Succeed.
# NNG_5  2013  Succeed.
# NNG_5  2014  Succeed.
# NNG_5  2015  Succeed.
# NNG_5  2016  Succeed.
# NNG_5  2017  Succeed.
# NNG_5  2018  Succeed.
# NNG_5  2019  Succeed.
# NNG_5  2020  Succeed.

# %%
# 绘制检验
def nng_distribution(m):
    distribution = np.array([np.load(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_NNG_global_china_{m}_year\\MappingXCO2_{year}.npy")
                             for year in range(2014, 2021)]).mean(axis=0)
    map_plot_surface(distribution, "viridis", None, None, f"N{str(m).zfill(2)}: Seven-year average distribution", figsize=(8, 8))

nng_distribution(5)
# Out:
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
def bkg_distribution(m):
    distribution = np.array([np.load(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_NNG_global_china_{m}_year\\MappingXCO2_{year}.npy")
                             for year in range(2014, 2021)]).mean(axis=0)
    xco2 = np.array([np.load(f"H:\\XCO2\\MappingXCO2\\MappingXCO2_year\\MappingXCO2_{year}.npy")
                     for year in range(2014, 2021)]).mean(axis=0)
    bkg = xco2 - distribution
    map_plot_surface(bkg, "viridis", None, None, f"N{str(m).zfill(2)}-bkg: Seven-year average distribution", figsize=(8, 8))

bkg_distribution(5)
# Out:
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
dxco2_gen(10)
dxco2_year_gen(10)
nng_distribution(10)
bkg_distribution(10)
# Out:
# NGG_10  MappingXCO2_201001.npy  Succeed.
# NGG_10  MappingXCO2_201002.npy  Succeed.
# NGG_10  MappingXCO2_201003.npy  Succeed.
# NGG_10  MappingXCO2_201004.npy  Succeed.
# NGG_10  MappingXCO2_201005.npy  Succeed.
# NGG_10  MappingXCO2_201006.npy  Succeed.
# NGG_10  MappingXCO2_201007.npy  Succeed.
# NGG_10  MappingXCO2_201008.npy  Succeed.
# NGG_10  MappingXCO2_201009.npy  Succeed.
# NGG_10  MappingXCO2_201010.npy  Succeed.
# NGG_10  MappingXCO2_201011.npy  Succeed.
# NGG_10  MappingXCO2_201012.npy  Succeed.
# NGG_10  MappingXCO2_201101.npy  Succeed.
# NGG_10  MappingXCO2_201102.npy  Succeed.
# NGG_10  MappingXCO2_201103.npy  Succeed.
# NGG_10  MappingXCO2_201104.npy  Succeed.
# NGG_10  MappingXCO2_201105.npy  Succeed.
# NGG_10  MappingXCO2_201106.npy  Succeed.
# NGG_10  MappingXCO2_201107.npy  Succeed.
# NGG_10  MappingXCO2_201108.npy  Succeed.
# NGG_10  MappingXCO2_201109.npy  Succeed.
# NGG_10  MappingXCO2_201110.npy  Succeed.
# NGG_10  MappingXCO2_201111.npy  Succeed.
# NGG_10  MappingXCO2_201112.npy  Succeed.
# NGG_10  MappingXCO2_201201.npy  Succeed.
# NGG_10  MappingXCO2_201202.npy  Succeed.
# NGG_10  MappingXCO2_201203.npy  Succeed.
# NGG_10  MappingXCO2_201204.npy  Succeed.
# NGG_10  MappingXCO2_201205.npy  Succeed.
# NGG_10  MappingXCO2_201206.npy  Succeed.
# NGG_10  MappingXCO2_201207.npy  Succeed.
# NGG_10  MappingXCO2_201208.npy  Succeed.
# NGG_10  MappingXCO2_201209.npy  Succeed.
# NGG_10  MappingXCO2_201210.npy  Succeed.
# NGG_10  MappingXCO2_201211.npy  Succeed.
# NGG_10  MappingXCO2_201212.npy  Succeed.
# NGG_10  MappingXCO2_201301.npy  Succeed.
# NGG_10  MappingXCO2_201302.npy  Succeed.
# NGG_10  MappingXCO2_201303.npy  Succeed.
# NGG_10  MappingXCO2_201304.npy  Succeed.
# NGG_10  MappingXCO2_201305.npy  Succeed.
# NGG_10  MappingXCO2_201306.npy  Succeed.
# NGG_10  MappingXCO2_201307.npy  Succeed.
# NGG_10  MappingXCO2_201308.npy  Succeed.
# NGG_10  MappingXCO2_201309.npy  Succeed.
# NGG_10  MappingXCO2_201310.npy  Succeed.
# NGG_10  MappingXCO2_201311.npy  Succeed.
# NGG_10  MappingXCO2_201312.npy  Succeed.
# NGG_10  MappingXCO2_201401.npy  Succeed.
# NGG_10  MappingXCO2_201402.npy  Succeed.
# NGG_10  MappingXCO2_201403.npy  Succeed.
# NGG_10  MappingXCO2_201404.npy  Succeed.
# NGG_10  MappingXCO2_201405.npy  Succeed.
# NGG_10  MappingXCO2_201406.npy  Succeed.
# NGG_10  MappingXCO2_201407.npy  Succeed.
# NGG_10  MappingXCO2_201408.npy  Succeed.
# NGG_10  MappingXCO2_201409.npy  Succeed.
# NGG_10  MappingXCO2_201410.npy  Succeed.
# NGG_10  MappingXCO2_201411.npy  Succeed.
# NGG_10  MappingXCO2_201412.npy  Succeed.
# NGG_10  MappingXCO2_201501.npy  Succeed.
# NGG_10  MappingXCO2_201502.npy  Succeed.
# NGG_10  MappingXCO2_201503.npy  Succeed.
# NGG_10  MappingXCO2_201504.npy  Succeed.
# NGG_10  MappingXCO2_201505.npy  Succeed.
# NGG_10  MappingXCO2_201506.npy  Succeed.
# NGG_10  MappingXCO2_201507.npy  Succeed.
# NGG_10  MappingXCO2_201508.npy  Succeed.
# NGG_10  MappingXCO2_201509.npy  Succeed.
# NGG_10  MappingXCO2_201510.npy  Succeed.
# NGG_10  MappingXCO2_201511.npy  Succeed.
# NGG_10  MappingXCO2_201512.npy  Succeed.
# NGG_10  MappingXCO2_201601.npy  Succeed.
# NGG_10  MappingXCO2_201602.npy  Succeed.
# NGG_10  MappingXCO2_201603.npy  Succeed.
# NGG_10  MappingXCO2_201604.npy  Succeed.
# NGG_10  MappingXCO2_201605.npy  Succeed.
# NGG_10  MappingXCO2_201606.npy  Succeed.
# NGG_10  MappingXCO2_201607.npy  Succeed.
# NGG_10  MappingXCO2_201608.npy  Succeed.
# NGG_10  MappingXCO2_201609.npy  Succeed.
# NGG_10  MappingXCO2_201610.npy  Succeed.
# NGG_10  MappingXCO2_201611.npy  Succeed.
# NGG_10  MappingXCO2_201612.npy  Succeed.
# NGG_10  MappingXCO2_201701.npy  Succeed.
# NGG_10  MappingXCO2_201702.npy  Succeed.
# NGG_10  MappingXCO2_201703.npy  Succeed.
# NGG_10  MappingXCO2_201704.npy  Succeed.
# NGG_10  MappingXCO2_201705.npy  Succeed.
# NGG_10  MappingXCO2_201706.npy  Succeed.
# NGG_10  MappingXCO2_201707.npy  Succeed.
# NGG_10  MappingXCO2_201708.npy  Succeed.
# NGG_10  MappingXCO2_201709.npy  Succeed.
# NGG_10  MappingXCO2_201710.npy  Succeed.
# NGG_10  MappingXCO2_201711.npy  Succeed.
# NGG_10  MappingXCO2_201712.npy  Succeed.
# NGG_10  MappingXCO2_201801.npy  Succeed.
# NGG_10  MappingXCO2_201802.npy  Succeed.
# NGG_10  MappingXCO2_201803.npy  Succeed.
# NGG_10  MappingXCO2_201804.npy  Succeed.
# NGG_10  MappingXCO2_201805.npy  Succeed.
# NGG_10  MappingXCO2_201806.npy  Succeed.
# NGG_10  MappingXCO2_201807.npy  Succeed.
# NGG_10  MappingXCO2_201808.npy  Succeed.
# NGG_10  MappingXCO2_201809.npy  Succeed.
# NGG_10  MappingXCO2_201810.npy  Succeed.
# NGG_10  MappingXCO2_201811.npy  Succeed.
# NGG_10  MappingXCO2_201812.npy  Succeed.
# NGG_10  MappingXCO2_201901.npy  Succeed.
# NGG_10  MappingXCO2_201902.npy  Succeed.
# NGG_10  MappingXCO2_201903.npy  Succeed.
# NGG_10  MappingXCO2_201904.npy  Succeed.
# NGG_10  MappingXCO2_201905.npy  Succeed.
# NGG_10  MappingXCO2_201906.npy  Succeed.
# NGG_10  MappingXCO2_201907.npy  Succeed.
# NGG_10  MappingXCO2_201908.npy  Succeed.
# NGG_10  MappingXCO2_201909.npy  Succeed.
# NGG_10  MappingXCO2_201910.npy  Succeed.
# NGG_10  MappingXCO2_201911.npy  Succeed.
# NGG_10  MappingXCO2_201912.npy  Succeed.
# NGG_10  MappingXCO2_202001.npy  Succeed.
# NGG_10  MappingXCO2_202002.npy  Succeed.
# NGG_10  MappingXCO2_202003.npy  Succeed.
# NGG_10  MappingXCO2_202004.npy  Succeed.
# NGG_10  MappingXCO2_202005.npy  Succeed.
# NGG_10  MappingXCO2_202006.npy  Succeed.
# NGG_10  MappingXCO2_202007.npy  Succeed.
# NGG_10  MappingXCO2_202008.npy  Succeed.
# NGG_10  MappingXCO2_202009.npy  Succeed.
# NGG_10  MappingXCO2_202010.npy  Succeed.
# NGG_10  MappingXCO2_202011.npy  Succeed.
# NGG_10  MappingXCO2_202012.npy  Succeed.
# NNG_10  2010  Succeed.
# NNG_10  2011  Succeed.
# NNG_10  2012  Succeed.
# NNG_10  2013  Succeed.
# NNG_10  2014  Succeed.
# NNG_10  2015  Succeed.
# NNG_10  2016  Succeed.
# NNG_10  2017  Succeed.
# NNG_10  2018  Succeed.
# NNG_10  2019  Succeed.
# NNG_10  2020  Succeed.
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
dxco2_gen(15)
dxco2_year_gen(15)
nng_distribution(15)
bkg_distribution(15)
# Out:
# NGG_15  MappingXCO2_201001.npy  Succeed.
# NGG_15  MappingXCO2_201002.npy  Succeed.
# NGG_15  MappingXCO2_201003.npy  Succeed.
# NGG_15  MappingXCO2_201004.npy  Succeed.
# NGG_15  MappingXCO2_201005.npy  Succeed.
# NGG_15  MappingXCO2_201006.npy  Succeed.
# NGG_15  MappingXCO2_201007.npy  Succeed.
# NGG_15  MappingXCO2_201008.npy  Succeed.
# NGG_15  MappingXCO2_201009.npy  Succeed.
# NGG_15  MappingXCO2_201010.npy  Succeed.
# NGG_15  MappingXCO2_201011.npy  Succeed.
# NGG_15  MappingXCO2_201012.npy  Succeed.
# NGG_15  MappingXCO2_201101.npy  Succeed.
# NGG_15  MappingXCO2_201102.npy  Succeed.
# NGG_15  MappingXCO2_201103.npy  Succeed.
# NGG_15  MappingXCO2_201104.npy  Succeed.
# NGG_15  MappingXCO2_201105.npy  Succeed.
# NGG_15  MappingXCO2_201106.npy  Succeed.
# NGG_15  MappingXCO2_201107.npy  Succeed.
# NGG_15  MappingXCO2_201108.npy  Succeed.
# NGG_15  MappingXCO2_201109.npy  Succeed.
# NGG_15  MappingXCO2_201110.npy  Succeed.
# NGG_15  MappingXCO2_201111.npy  Succeed.
# NGG_15  MappingXCO2_201112.npy  Succeed.
# NGG_15  MappingXCO2_201201.npy  Succeed.
# NGG_15  MappingXCO2_201202.npy  Succeed.
# NGG_15  MappingXCO2_201203.npy  Succeed.
# NGG_15  MappingXCO2_201204.npy  Succeed.
# NGG_15  MappingXCO2_201205.npy  Succeed.
# NGG_15  MappingXCO2_201206.npy  Succeed.
# NGG_15  MappingXCO2_201207.npy  Succeed.
# NGG_15  MappingXCO2_201208.npy  Succeed.
# NGG_15  MappingXCO2_201209.npy  Succeed.
# NGG_15  MappingXCO2_201210.npy  Succeed.
# NGG_15  MappingXCO2_201211.npy  Succeed.
# NGG_15  MappingXCO2_201212.npy  Succeed.
# NGG_15  MappingXCO2_201301.npy  Succeed.
# NGG_15  MappingXCO2_201302.npy  Succeed.
# NGG_15  MappingXCO2_201303.npy  Succeed.
# NGG_15  MappingXCO2_201304.npy  Succeed.
# NGG_15  MappingXCO2_201305.npy  Succeed.
# NGG_15  MappingXCO2_201306.npy  Succeed.
# NGG_15  MappingXCO2_201307.npy  Succeed.
# NGG_15  MappingXCO2_201308.npy  Succeed.
# NGG_15  MappingXCO2_201309.npy  Succeed.
# NGG_15  MappingXCO2_201310.npy  Succeed.
# NGG_15  MappingXCO2_201311.npy  Succeed.
# NGG_15  MappingXCO2_201312.npy  Succeed.
# NGG_15  MappingXCO2_201401.npy  Succeed.
# NGG_15  MappingXCO2_201402.npy  Succeed.
# NGG_15  MappingXCO2_201403.npy  Succeed.
# NGG_15  MappingXCO2_201404.npy  Succeed.
# NGG_15  MappingXCO2_201405.npy  Succeed.
# NGG_15  MappingXCO2_201406.npy  Succeed.
# NGG_15  MappingXCO2_201407.npy  Succeed.
# NGG_15  MappingXCO2_201408.npy  Succeed.
# NGG_15  MappingXCO2_201409.npy  Succeed.
# NGG_15  MappingXCO2_201410.npy  Succeed.
# NGG_15  MappingXCO2_201411.npy  Succeed.
# NGG_15  MappingXCO2_201412.npy  Succeed.
# NGG_15  MappingXCO2_201501.npy  Succeed.
# NGG_15  MappingXCO2_201502.npy  Succeed.
# NGG_15  MappingXCO2_201503.npy  Succeed.
# NGG_15  MappingXCO2_201504.npy  Succeed.
# NGG_15  MappingXCO2_201505.npy  Succeed.
# NGG_15  MappingXCO2_201506.npy  Succeed.
# NGG_15  MappingXCO2_201507.npy  Succeed.
# NGG_15  MappingXCO2_201508.npy  Succeed.
# NGG_15  MappingXCO2_201509.npy  Succeed.
# NGG_15  MappingXCO2_201510.npy  Succeed.
# NGG_15  MappingXCO2_201511.npy  Succeed.
# NGG_15  MappingXCO2_201512.npy  Succeed.
# NGG_15  MappingXCO2_201601.npy  Succeed.
# NGG_15  MappingXCO2_201602.npy  Succeed.
# NGG_15  MappingXCO2_201603.npy  Succeed.
# NGG_15  MappingXCO2_201604.npy  Succeed.
# NGG_15  MappingXCO2_201605.npy  Succeed.
# NGG_15  MappingXCO2_201606.npy  Succeed.
# NGG_15  MappingXCO2_201607.npy  Succeed.
# NGG_15  MappingXCO2_201608.npy  Succeed.
# NGG_15  MappingXCO2_201609.npy  Succeed.
# NGG_15  MappingXCO2_201610.npy  Succeed.
# NGG_15  MappingXCO2_201611.npy  Succeed.
# NGG_15  MappingXCO2_201612.npy  Succeed.
# NGG_15  MappingXCO2_201701.npy  Succeed.
# NGG_15  MappingXCO2_201702.npy  Succeed.
# NGG_15  MappingXCO2_201703.npy  Succeed.
# NGG_15  MappingXCO2_201704.npy  Succeed.
# NGG_15  MappingXCO2_201705.npy  Succeed.
# NGG_15  MappingXCO2_201706.npy  Succeed.
# NGG_15  MappingXCO2_201707.npy  Succeed.
# NGG_15  MappingXCO2_201708.npy  Succeed.
# NGG_15  MappingXCO2_201709.npy  Succeed.
# NGG_15  MappingXCO2_201710.npy  Succeed.
# NGG_15  MappingXCO2_201711.npy  Succeed.
# NGG_15  MappingXCO2_201712.npy  Succeed.
# NGG_15  MappingXCO2_201801.npy  Succeed.
# NGG_15  MappingXCO2_201802.npy  Succeed.
# NGG_15  MappingXCO2_201803.npy  Succeed.
# NGG_15  MappingXCO2_201804.npy  Succeed.
# NGG_15  MappingXCO2_201805.npy  Succeed.
# NGG_15  MappingXCO2_201806.npy  Succeed.
# NGG_15  MappingXCO2_201807.npy  Succeed.
# NGG_15  MappingXCO2_201808.npy  Succeed.
# NGG_15  MappingXCO2_201809.npy  Succeed.
# NGG_15  MappingXCO2_201810.npy  Succeed.
# NGG_15  MappingXCO2_201811.npy  Succeed.
# NGG_15  MappingXCO2_201812.npy  Succeed.
# NGG_15  MappingXCO2_201901.npy  Succeed.
# NGG_15  MappingXCO2_201902.npy  Succeed.
# NGG_15  MappingXCO2_201903.npy  Succeed.
# NGG_15  MappingXCO2_201904.npy  Succeed.
# NGG_15  MappingXCO2_201905.npy  Succeed.
# NGG_15  MappingXCO2_201906.npy  Succeed.
# NGG_15  MappingXCO2_201907.npy  Succeed.
# NGG_15  MappingXCO2_201908.npy  Succeed.
# NGG_15  MappingXCO2_201909.npy  Succeed.
# NGG_15  MappingXCO2_201910.npy  Succeed.
# NGG_15  MappingXCO2_201911.npy  Succeed.
# NGG_15  MappingXCO2_201912.npy  Succeed.
# NGG_15  MappingXCO2_202001.npy  Succeed.
# NGG_15  MappingXCO2_202002.npy  Succeed.
# NGG_15  MappingXCO2_202003.npy  Succeed.
# NGG_15  MappingXCO2_202004.npy  Succeed.
# NGG_15  MappingXCO2_202005.npy  Succeed.
# NGG_15  MappingXCO2_202006.npy  Succeed.
# NGG_15  MappingXCO2_202007.npy  Succeed.
# NGG_15  MappingXCO2_202008.npy  Succeed.
# NGG_15  MappingXCO2_202009.npy  Succeed.
# NGG_15  MappingXCO2_202010.npy  Succeed.
# NGG_15  MappingXCO2_202011.npy  Succeed.
# NGG_15  MappingXCO2_202012.npy  Succeed.
# NNG_15  2010  Succeed.
# NNG_15  2011  Succeed.
# NNG_15  2012  Succeed.
# NNG_15  2013  Succeed.
# NNG_15  2014  Succeed.
# NNG_15  2015  Succeed.
# NNG_15  2016  Succeed.
# NNG_15  2017  Succeed.
# NNG_15  2018  Succeed.
# NNG_15  2019  Succeed.
# NNG_15  2020  Succeed.
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)
# H:\preprocessing_code\XCO2\NNG\maplot.py:62: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   mapPlot = Map.pcolor(x, y, m, cmap=cmap, vmin=vmin, vmax=vmax)
